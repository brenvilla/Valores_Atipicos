# %% [markdown]
# <a href="https://colab.research.google.com/github/brenvilla/Valores_Atipicos/blob/main/Actividad3_1_Valores_Atipicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Actividad 3.1 (Valores Atípicos)**
#
# Brenda Villa Campos A01732238

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-567bb504-5dff-44f1-937d-a9bbf6ff730c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-567bb504-5dff-44f1-937d-a9bbf6ff730c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df= pd.read_csv('Ventas_totales.csv')
df
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %% [markdown]
# ### **Reemplazamiento de valores nulos**

# %%
#Corroboramos valores nulos
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                           0
# ventas_precios_corrientes               0
# ventas_precios_constantes               0
# ventas_totales_canal_venta              0
# salon_ventas                            6
# canales_on_line                         0
# ventas_totales_medio_pago               0
# efectivo                                0
# tarjetas_debito                         1
# tarjetas_credito                        7
# otros_medios                            1
# ventas_totales_grupo_articulos          0
# subtotal_ventas_alimentos_bebidas      10
# bebidas                                 1
# almacen                                 2
# panaderia                               1
# lacteos                                 1
# carnes                                  1
# verduleria_fruteria                     1
# alimentos_preparados_rotiseria          1
# articulos_limpieza_perfumeria           0
# indumentaria_calzado_textiles_hogar     2
# ...

# %%
#Sustitución de valores nulos de la columna "subtotal_ventas_alimentos_bebidas"
#por el promedio

df["subtotal_ventas_alimentos_bebidas"]=df["subtotal_ventas_alimentos_bebidas"].fillna(round(df["subtotal_ventas_alimentos_bebidas"].mean(),1))

# %%
#Sustitución de los valores nulos de la columna "tarjetas_debito" por la mediana
#de la misma

df["tarjetas_debito"]=df["tarjetas_debito"].fillna(round(df["tarjetas_debito"].median(),1))

# %%
#Sustitución de valores nulos de la columna "tarjetas_credito" por el valor 20

df["tarjetas_credito"]=df["tarjetas_credito"].fillna(20)

# %%
#Sustitución de valores nulos de la columna "salon_ventas" por el string "Datos faltantes"

df["salon_ventas"]=df["salon_ventas"].fillna(0)

# %%
#Sustitución de valores nulos de la columna "otros_medios" por el valor anterior

df["otros_medios"]=df["otros_medios"].fillna(method="ffill")

# %%
#Sustitución de valores nulos de la columna "bebidas" por el valor posterior o que sigue

df["bebidas"]=df["bebidas"].fillna(method="bfill")

# %%
##Sustitución de valores nulos de la columna "almacen" por el valor posterior o que sigue
df["almacen"]=df["almacen"].fillna(method="bfill")

# %%
#Sustitución de valores nulos de la columna "panaderia" por el promedio
df["panaderia"]=df["panaderia"].fillna(round(df["panaderia"].mean(),1))

# %%
#Sustitución de valores nulos de la columa "lacteos" por la mediana
df["lacteos"]=df["lacteos"].fillna(round(df["lacteos"].median(),1))

# %%
#Sustitución de valores nulos de la columna "carnes" por el dígito 30
df["carnes"]=df["carnes"].fillna(30)

# %%
# Sustitución de valores nulos de la columna "verduleria_fruteria" por la expresión "00 00"
df["verduleria_fruteria"]=df["verduleria_fruteria"].fillna(0)

# %%
#Sustitución de valores nulos de la columna "alimentos_preparados_rotiseria" por el valor anterior
df["alimentos_preparados_rotiseria"]=df["alimentos_preparados_rotiseria"].fillna(method="ffill")

# %%
#Sustitución de valores nulos de la columna "indumentaria_calzado_textiles_hogar" por el valor posterior
df["indumentaria_calzado_textiles_hogar"]=df["indumentaria_calzado_textiles_hogar"].fillna(method="bfill")

# %%
#Sustitución de valores nulos de la columna "electronicos_articulos_hogar" por el valor posterior
df["electronicos_articulos_hogar"]=df["electronicos_articulos_hogar"].fillna(method="bfill")

# %%
#Sustitución de valores nulos de la columna "otros" por la cadena "--"
df["otros"]=df["otros"].fillna(0)

# %%
#Comprobación de valores nulos existentes
valores_nulos=df.isnull().sum()
valores_nulos
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# electronicos_articulos_hogar           0
# ...

# %%
#Total de valores nulos en todo el dataframe
valores_nulos=df.isnull().sum().sum()
valores_nulos
# Out:
# 0

# %%
VentasTotales_sin_nulos=df
VentasTotales_sin_nulos.to_csv("VentasTotales_sin_nulos.csv")
files.download("VentasTotales_sin_nulos.csv")

# %% [markdown]
# ## **Eliminación de Outliers por columna**

# %% [markdown]
# ### **Variable 1: ventas_precios_corrientes**

# %%
#Método de desviación estandar 
y=df["ventas_precios_corrientes"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 214312.62398613384
# Limite inferior permitido -69832.22706305691

# %%
#Encontramos Ouliers
outliers= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["ventas_precios_corrientes"]) 
plt.title("Outliers de ventas_precios_corrientes")
plt.show() #dibujamos el diagrama

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["ventas_precios_corrientes"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 192319.35000000003
# Limite inferior permitido -59178.650000000016

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 42    01/07/2020                   211140.7                    50791.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 42                 81140696.22   76413721.76      4726974.457
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 42                81140696.22  24935747.29      22143208.63        29569224.4
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 42  ...  23393038.41  2630487.791  9592798.115  8463266.123
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                     518942.5376
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 42                    11217153.19                          2502616.619
#
#     electronicos_articulos_hogar        otros
# 42                   6125265.839  5935993.913
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["ventas_precios_corrientes"]) 
plt.title("Outliers de ventas_precios_corrientes")
plt.show() #dibujamos el diagrama

# %%
col_1=data_clean_iqr["ventas_precios_corrientes"]
col_1.to_csv("clean__iqr_ventas_precios_corrientes.csv")
files.download("clean__iqr_ventas_precios_corrientes.csv")

# %% [markdown]
# ### **Variable 2: ventas_precios_constantes**

# %%
#Método de desviación estandar 
y=df["ventas_precios_constantes"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 40022.90598479884
# Limite inferior permitido 12104.484784431932

# %%
#Encontramos Ouliers
outliers= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 42    01/07/2020                   211140.7                    50791.4
# 60    01/01/2022                   154517.1                    45463.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 42                8.114070e+07  7.641372e+07      4726974.457
# 60                1.545171e+08  1.496976e+08      4819479.554
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 42               8.114070e+07  24935747.29      22143208.63       29569224.40
# 60               1.545171e+08  46962602.22      46053650.13       54048333.12
#
#     ...      almacen    panaderia       lacteos        carnes  \
# 42  ...  23393038.41  2630487.791  9.592798e+06  8.463266e+06
# 60  ...  37505172.62  4860317.680  1.610477e+07  1.740849e+07
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                    5.189425e+05
# ...

# %%
#Obtenemos datos limpios
data_clean= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["ventas_precios_constantes"]) 
plt.title("Outliers de ventas_precios_constantes")
plt.show() #dibujamos el diagrama

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["ventas_precios_constantes"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 31938.75
# Limite inferior permitido 18759.949999999997

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 11    01/12/2017                    40766.3                    34084.5
# 42    01/07/2020                   211140.7                    50791.4
# 60    01/01/2022                   154517.1                    45463.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 11                4.076632e+07  4.032029e+07     4.460368e+05
# 42                8.114070e+07  7.641372e+07     4.726974e+06
# 60                1.545171e+08  1.496976e+08     4.819480e+06
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 11               4.076632e+07  13710305.37      11070098.74       14576008.24
# 42               8.114070e+07  24935747.29      22143208.63       29569224.40
# 60               1.545171e+08  46962602.22      46053650.13       54048333.12
#
#     ...       almacen    panaderia       lacteos        carnes  \
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["ventas_precios_constantes"]) 
plt.title("Outliers de ventas_precios_constantes")
plt.show() #dibujamos el diagrama

# %%
col_2=data_clean_iqr["ventas_precios_constantes"]
col_2.to_csv("clean__iqr_ventas_precios_constantes.csv")
files.download("clean__iqr_ventas_precios_constantes.csv")

# %% [markdown]
# ### **Variable 3: ventas_totales_canal_venta**

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["ventas_totales_canal_venta"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 187511643.5
# Limite inferior permitido -51165850.5

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Con el método IQR no se encontraron outliers, por lo que esta columna no se toma en cuenta

# %% [markdown]
# ### **Variable 4: salon_ventas**

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["salon_ventas"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 188156701.385
# Limite inferior permitido -61529048.254999995

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Con el método IQR no se encontraron outliers, por lo que esta columna no se toma en cuenta

# %% [markdown]
# ### **Variable 5: canales_on_line**

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["canales_on_line"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 9196780.92675
# Limite inferior permitido -4707517.02725

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Con el método IQR no se encontraron outliers, por lo que esta columna no se toma en cuenta

# %% [markdown]
# ### **Variable 6: ventas_totales_medio_pago**

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["ventas_totales_medio_pago"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 187511643.5
# Limite inferior permitido -51165850.5

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Con el método IQR no se encontraron outliers, por lo que esta columna no se toma en cuenta

# %% [markdown]
# ### **Variable 7: efectivo**

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["efectivo"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 59420215.78999999
# Limite inferior permitido -14024584.689999996

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Con el método IQR no se encontraron outliers, por lo que esta columna no se toma en cuenta

# %% [markdown]
# ### **Variable 8: tarjetas_debito**

# %%
#Método de desviación estandar 
y=df["tarjetas_debito"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 58179494.9472643
# Limite inferior permitido -18390283.63738738

# %%
#Encontramos Ouliers
outliers= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["tarjetas_debito"]) 
plt.title("Outliers de tarjetas_debito")
plt.show() #dibujamos el diagrama

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["tarjetas_debito"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 50952216.5835
# Limite inferior permitido -15349161.052499998

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2      5116430.634
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37       62999676.15
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["tarjetas_debito"]) 
plt.title("Outliers de tarjetas_debito")
plt.show() #dibujamos el diagrama

# %%
col_8=data_clean_iqr["tarjetas_debito"]
col_8.to_csv("clean_iqr_tarjetas_debito.csv")
files.download("clean_iqr_tarjetas_debito.csv")

# %% [markdown]
# ### **Variable 9: tarjetas_credito**

# %%
#Método de desviación estandar 
y=df["tarjetas_credito"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 76112010.53014472
# Limite inferior permitido -27459829.946821652

# %%
#Encontramos Ouliers
outliers= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["tarjetas_credito"]) 
plt.title("Outliers de tarjetas_credito")
plt.show() #dibujamos el diagrama

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["tarjetas_credito"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 67245047.49000001
# Limite inferior permitido -22163587.950000007

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 64                 179639238.6   175358487.5      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 64                179639238.6  52738110.62      49886787.86       68070088.23
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 64           6314109.47                     1779482.857
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 64                    23578638.71                          5213152.564
#
#     electronicos_articulos_hogar        otros
# 64                   12039595.55  12349980.06
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["tarjetas_credito"]) 
plt.title("Outliers de tarjetas_credito")
plt.show() #dibujamos el diagrama

# %%
col_9=data_clean_iqr["tarjetas_credito"]
col_9.to_csv("clean_iqr_tarjetas_credito.csv")
files.download("clean_iqr_tarjetas_credito.csv")

# %% [markdown]
# ### **Variable 10: otros_medios**

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["otros_medios"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 10650466.405000001
# Limite inferior permitido -3781032.139000001

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Con el método IQR no se encontraron outliers, por lo que esta columna no se toma en cuenta

# %% [markdown]
# ### **Variable 11: ventas_totales_grupo_articulos**

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["ventas_totales_grupo_articulos"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 187511643.5
# Limite inferior permitido -51165850.5

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Con el método IQR no se encontraron outliers, por lo que esta columna no se toma en cuenta

# %% [markdown]
# ### **Variable 12: subtotal_ventas_alimentos_bebidas**

# %%
#Método de desviación estandar 
y=df["subtotal_ventas_alimentos_bebidas"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 143021333.08929762
# Limite inferior permitido -32426087.265605308

# %%
#Encontramos Ouliers
outliers= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["subtotal_ventas_alimentos_bebidas"]) 
plt.title("Outliers de subtotal_ventas_alimentos_bebidas")
plt.show() #dibujamos el diagrama

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["subtotal_ventas_alimentos_bebidas"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 114548006.925
# Limite inferior permitido -11790048.954999998

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2     5.116431e+06
# 62                 168982502.3   164321107.3     4.661350e+05
# 63                 177148082.8   173003799.1     4.144284e+06
# 64                 179639238.6   175358487.5     4.280751e+06
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37       62999676.15
# 62                168982502.3  51262080.99      47364363.88             20.00
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["subtotal_ventas_alimentos_bebidas"]) 
plt.title("Outliers de subtotal_ventas_alimentos_bebidas")
plt.show() #dibujamos el diagrama

# %%
col_12=data_clean_iqr["subtotal_ventas_alimentos_bebidas"]
col_12.to_csv("clean_iqr_subtotal_ventas_alimentos_bebidas.csv")
files.download("clean_iqr_subtotal_ventas_alimentos_bebidas.csv")

# %% [markdown]
# ### **Variable 13: bebidas**

# %%
#Método de desviación estandar 
y=df["bebidas"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 26527222.51555183
# Limite inferior permitido -8711926.909151834

# %%
#Encontramos Ouliers
outliers= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2      5116430.634
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37       62999676.15
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["bebidas"]) 
plt.title("Outliers de bebidas")
plt.show() #dibujamos el diagrama

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["bebidas"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 22825184.4515
# Limite inferior permitido -6724636.7525

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2      5116430.634
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37       62999676.15
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["bebidas"]) 
plt.title("Outliers de bebidas")
plt.show() #dibujamos el diagrama

# %%
col_13=data_clean_iqr["bebidas"]
col_13.to_csv("clean_iqr_bebidas.csv")
files.download("clean_iqr_bebidas.csv")

# %% [markdown]
# ### **Variable 14: almacen**

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["almacen"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 50755333.115499996
# Limite inferior permitido -14779676.552499996

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Con el método IQR no se encontraron outliers, por lo que esta columna no se toma en cuenta

# %% [markdown]
# ### **Variable 15: panaderia**

# %%
#Método de desviación estandar 
y=df["panaderia"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 6907606.7495621145
# Limite inferior permitido -1821126.3505928833

# %%
#Encontramos Ouliers
outliers= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["panaderia"]) 
plt.title("Outliers de panaderia")
plt.show() #dibujamos el diagrama

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["panaderia"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 5314390.465
# Limite inferior permitido -928804.111

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2     5.116431e+06
# 62                 168982502.3   164321107.3     4.661350e+05
# 63                 177148082.8   173003799.1     4.144284e+06
# 64                 179639238.6   175358487.5     4.280751e+06
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37       62999676.15
# 62                168982502.3  51262080.99      47364363.88             20.00
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["panaderia"]) 
plt.title("Outliers de panaderia")
plt.show() #dibujamos el diagrama

# %%
col_15=data_clean_iqr["panaderia"]
col_15.to_csv("clean_iqr_panaderia.csv")
files.download("clean_iqr_panaderia.csv")

# %% [markdown]
# ### **Variable 16: lacteos**

# %%
#Método de desviación estandar 
y=df["lacteos"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 22228243.902642798
# Limite inferior permitido -5875706.997812029

# %%
#Encontramos Ouliers
outliers= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["lacteos"]) 
plt.title("Outliers de lacteos")
plt.show() #dibujamos el diagrama

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["lacteos"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 19940661.0455
# Limite inferior permitido -5569362.3025

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 64                 179639238.6   175358487.5      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 64                179639238.6  52738110.62      49886787.86       68070088.23
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 64           6314109.47                     1779482.857
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 64                    23578638.71                          5213152.564
#
#     electronicos_articulos_hogar        otros
# 64                   12039595.55  12349980.06
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["lacteos"]) 
plt.title("Outliers de lacteos")
plt.show() #dibujamos el diagrama

# %%
col_16=data_clean_iqr["lacteos"]
col_16.to_csv("clean_iqr_lacteos.csv")
files.download("clean_iqr_lacteos.csv")

# %% [markdown]
# ### **Variable 17: carnes**

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["carnes"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 23968996.893999998
# Limite inferior permitido -8565256.29

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Con el método IQR no se encontraron outliers, por lo que esta columna no se toma en cuenta

# %% [markdown]
# ### **Variable 18: verduleria_fruteria**

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["verduleria_fruteria"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 7865869.983
# Limite inferior permitido -2645314.985

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Con el método IQR no se encontraron outliers, por lo que esta columna no se toma en cuenta

# %% [markdown]
# ### **Variable 19: alimentos_preparados_rotiseria**

# %%
#Método de desviación estandar 
y=df["alimentos_preparados_rotiseria"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 1796605.7908211616
# Limite inferior permitido -421805.4176580849

# %%
#Encontramos Ouliers
outliers= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["alimentos_preparados_rotiseria"]) 
plt.title("Outliers de alimentos_preparados_rotiseria")
plt.show() #dibujamos el diagrama

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["alimentos_preparados_rotiseria"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 1546751.13875
# Limite inferior permitido -227313.79444999993

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2     5.116431e+06
# 62                 168982502.3   164321107.3     4.661350e+05
# 63                 177148082.8   173003799.1     4.144284e+06
# 64                 179639238.6   175358487.5     4.280751e+06
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37       62999676.15
# 62                168982502.3  51262080.99      47364363.88             20.00
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["alimentos_preparados_rotiseria"]) 
plt.title("Outliers de alimentos_preparados_rotiseria")
plt.show() #dibujamos el diagrama

# %%
col_19=data_clean_iqr["alimentos_preparados_rotiseria"]
col_19.to_csv("clean_iqr_alimentos_preparados_rotiseria.csv")
files.download("clean_iqr_alimentos_preparados_rotiseria.csv")

# %% [markdown]
# ### **Variable 20: articulos_limpieza_perfumeria**

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["articulos_limpieza_perfumeria"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 27735459.188
# Limite inferior permitido -8258486.54

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Con el método IQR no se encontraron outliers, por lo que esta columna no se toma en cuenta

# %% [markdown]
# ### **Variable 21: indumentaria_calzado_textiles_hogar**

# %%
#Método de desviación estandar 
y=df["indumentaria_calzado_textiles_hogar"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 5206741.672536181
# Limite inferior permitido -1465741.789871566

# %%
#Encontramos Ouliers
outliers= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 64                 179639238.6   175358487.5      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 64                179639238.6  52738110.62      49886787.86       68070088.23
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 64           6314109.47                     1779482.857
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 64                    23578638.71                          5213152.564
#
#     electronicos_articulos_hogar        otros
# 64                   12039595.55  12349980.06
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["indumentaria_calzado_textiles_hogar"]) 
plt.title("Outliers de indumentaria_calzado_textiles_hogar")
plt.show() #dibujamos el diagrama

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["indumentaria_calzado_textiles_hogar"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 4028365.028
# Limite inferior permitido -800338.516

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 54    01/07/2021                   125658.6                    24779.5
# 59    01/12/2021                   183983.2                    31595.7
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 54                 125658552.5   120904098.3      4754454.215
# 59                 183983151.9   178866721.2      5116430.634
# 63                 177148082.8   173003799.1      4144283.743
# 64                 179639238.6   175358487.5      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 54                125658552.5  37973547.56      37146178.90       43727330.44
# 59                183983151.9  56640033.15      55432191.37       62999676.15
# ...

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["indumentaria_calzado_textiles_hogar"]) 
plt.title("Outliers de indumentaria_calzado_textiles_hogar")
plt.show() #dibujamos el diagrama

# %%
col_21=data_clean_iqr["indumentaria_calzado_textiles_hogar"]
col_21.to_csv("clean_iqr_indumentaria_calzado_textiles_hogar.csv")
files.download("clean_iqr_indumentaria_calzado_textiles_hogar.csv")

# %% [markdown]
# ### **Variable 22: electronicos_articulos_hogar**

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["electronicos_articulos_hogar"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 14042162.875500001
# Limite inferior permitido -4954693.8485

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Con el método IQR no se encontraron outliers, por lo que esta columna no se toma en cuenta

# %% [markdown]
# ### **Variable 23: otros**

# %%
#Método de desviación estandar 
y=df["otros"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 15951727.352466527
# Limite inferior permitido -5110613.031420373

# %%
#Encontramos Ouliers
outliers= df[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2      5116430.634
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37       62999676.15
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean= df[(y<=Limite_Superior)&(y>=Limite_Inferior)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean["otros"]) 
plt.title("Outliers de otros")
plt.show() #dibujamos el diagrama

# %%
#Método de IQR| Cuartiles 0.25 y 0.75 
y=df["otros"]

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 13645555.3675
# Limite inferior permitido -3393986.2364999987

# %%
#Encontramos Ouliers
outliers_iqr= df[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2      5116430.634
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37       62999676.15
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
data_clean_iqr= df[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 3))
plt.boxplot(data_clean_iqr["otros"]) 
plt.title("Outliers de otros")
plt.show() #dibujamos el diagrama

# %%
col_23=data_clean_iqr["otros"]
col_23.to_csv("clean_iqr_otros.csv")
files.download("clean_iqr_otros.csv")
